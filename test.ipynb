# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import json
from stockEnv import StockEnv
from TD3 import TD3
from OptiPhaseSpace import ChaoticFeatureExtractor
from kalmanfilter import apply_kalman_filter

# Load hyperparameters from JSON file
with open("best_params.json", "r") as f:
    params = json.load(f)

# Load trained agent
agent = torch.load('td3_agent.pth')
agent.eval()  # Set to evaluation mode
agent.exploration_phase = 0

# Load test data
data = np.load("data/test_data.npy")  

# Set test parameters
num_episodes = 10  # Small number for quick evaluation
num_stocks = data.shape[1]
initial_cash = 100_000
max_steps = data.shape[0]

# Apply Kalman filter using tuned parameters
data = apply_kalman_filter(data, 
                           observation_covariance=params["observation_covariance"], 
                           transition_covariance=params["transition_covariance"])

# Chaotic Feature Extractor setup
chaotic_extractor = ChaoticFeatureExtractor()
all_chaotic_features = chaotic_extractor.extract_features(data)
chaotic_feature_dim = chaotic_extractor.output_dim * num_stocks

# Environment setup
env = StockEnv(num_stocks=num_stocks, data=data, initial_cash=initial_cash)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]

reward_history = []
avg_reward_history = []
critic_loss_history = []

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0
    episode_critic_loss = []


    for step in range(max_steps):
        # Select action
        chaotic_features = all_chaotic_features[:, step, :].flatten() # (N*F*C)
        
        action = agent.select_action(
            state=state,
            chaotic_features=chaotic_features,
            current_episode=episode
        )

        print(f"Actions at step {step}: {action}")

        # Step in environment
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        next_chaotic_features = all_chaotic_features[:, step + 1, :].flatten() if step + 1 < max_steps else chaotic_features  # Handle last step case

        # Add transition to replay buffer
        agent.replay_buffer.add(
            (state, chaotic_features, action, reward, next_state,next_chaotic_features, done)
        )

        # Train the agent
        critic_loss,_ = agent.train(batch_size=params['batch_size'], discount=params['discount'], tau=params['tau'])
        episode_critic_loss.append(critic_loss)

        state = next_state

        if done:
            print(f"🚨 Episode {episode} ended early at step {step} due to termination condition.")

            break

    # Logging
    reward_history.append(total_reward)
    avg_reward = np.mean(reward_history[-10:])  # Moving average over last 10 episodes
    avg_reward_history.append(avg_reward)
    avg_critic_loss = np.mean(episode_critic_loss)
    critic_loss_history.append(avg_critic_loss)

    print(f"Episode {episode + 1}/{num_episodes}: Total Reward = {total_reward:.2f}, Avg Reward = {avg_reward:.2f}, Avg Critic Loss = {avg_critic_loss:.4f}")

# Plot rewards
plt.figure(figsize=(10, 5))
plt.plot(reward_history, label="Total Reward")
plt.plot(avg_reward_history, label="Average Reward")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("TD3 Training Rewards")
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(critic_loss_history, label="Critic Loss")
plt.xlabel("Episode")
plt.ylabel("Loss")
plt.title("TD3 Critic Loss Over Time")
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: pytest==6.2.5 in .\.conda\lib\site-packages (from -r requirements.txt (line 1)) (6.2.5)
# Requirement already satisfied: pandas==1.3.5 in .\.conda\lib\site-packages (from -r requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: scipy in .\.conda\lib\site-packages (from -r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: numpy==1.21.5 in .\.conda\lib\site-packages (from -r requirements.txt (line 4)) (1.21.5)
# Requirement already satisfied: scikit-learn==1.0.2 in .\.conda\lib\site-packages (from -r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: joblib in .\.conda\lib\site-packages (from -r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: uvicorn==0.17.5 in .\.conda\lib\site-packages (from -r requirements.txt (line 7)) (0.17.5)
# Requirement already satisfied: fastapi==0.74.0 in .\.conda\lib\site-packages (from -r requirements.txt (line 8)) (0.74.0)
# Requirement already satisfied: pydantic==1.9.0 in .\.conda\lib\site-packages (from -r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: wandb in .\.conda\lib\site-packages (from -r requirements.txt (line 10)) (0.18.7)
# Requirement already satisfied: attrs>=19.2.0 in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: iniconfig in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: packaging in c:\users\admin\appdata\roaming\python\python310\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: py>=1.8.2 in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: toml in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: atomicwrites>=1.0 in .\.conda\lib\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python310\site-packages (from pytest==6.2.5->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas==1.3.5->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in .\.conda\lib\site-packages (from pandas==1.3.5->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in .\.conda\lib\site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: asgiref>=3.4.0 in .\.conda\lib\site-packages (from uvicorn==0.17.5->-r requirements.txt (line 7)) (3.8.1)
# Requirement already satisfied: click>=7.0 in .\.conda\lib\site-packages (from uvicorn==0.17.5->-r requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: h11>=0.8 in .\.conda\lib\site-packages (from uvicorn==0.17.5->-r requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: starlette==0.17.1 in .\.conda\lib\site-packages (from fastapi==0.74.0->-r requirements.txt (line 8)) (0.17.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\.conda\lib\site-packages (from pydantic==1.9.0->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: anyio<4,>=3.0.0 in .\.conda\lib\site-packages (from starlette==0.17.1->fastapi==0.74.0->-r requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (3.1.44)
# Requirement already satisfied: platformdirs in c:\users\admin\appdata\roaming\python\python310\site-packages (from wandb->-r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from wandb->-r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: pyyaml in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (2.24.0)
# Requirement already satisfied: setproctitle in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (1.3.5)
# Requirement already satisfied: setuptools in .\.conda\lib\site-packages (from wandb->-r requirements.txt (line 10)) (75.8.0)
# Requirement already satisfied: six>=1.4.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from docker-pycreds>=0.4.0->wandb->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\.conda\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10)) (4.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\.conda\lib\site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in .\.conda\lib\site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.conda\lib\site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\.conda\lib\site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 10)) (2025.1.31)
# Requirement already satisfied: sniffio>=1.1 in .\.conda\lib\site-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi==0.74.0->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: exceptiongroup in .\.conda\lib\site-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi==0.74.0->-r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\.conda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 10)) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.
